# %% [markdown]
# ***导数***
# ![image.png](attachment:image.png)
#
# e.g : f(x) = 3x^2 - 4x

# %%
# %matplotlib inline
import numpy as np
from matplotlib_inline import backend_inline
import matplotlib.pyplot as plt

def f(x):
    return 3 * x**2 - 4 * x

# %%
# 无限逼近
def numerical_lim(f,x,h):
    return (f(x+h) - f(x)) / h

h = 0.1
for i in range(5):
    print(f'h={h:.5f},numerical limit={numerical_lim(f,1,h):.5f}')
    h *= 0.1
# Out:
# h=0.10000,numerical limit=2.30000
# h=0.01000,numerical limit=2.03000
# h=0.00100,numerical limit=2.00300
# h=0.00010,numerical limit=2.00030
# h=0.00001,numerical limit=2.00003

# %% [markdown]
# 可视化导数

# %%
# 使用svg格式在jupyter中显示绘图
def use_svg_display():
    backend_inline.set_matplotlib_formats('svg')

# %%
# 设置图表大小
def set_figsize(figsize=(3.5,2.5)):
    use_svg_display()
    plt.rcParams['figure.figsize'] = figsize

# %%
# 生成图表的轴属性 
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_xscale(xscale)
    axes.set_yscale(yscale)
    axes.set_xlim(xlim)
    axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

# %%
# 绘图
def plot(X,Y=None, xlabel=None, ylabel=None, legend=None, xlim=None, ylim=None,
        xscale='linear', yscale='linear', 
        fmts=('-','m--','g-.','r:'),figsize=(3.5,2.5),axes=None):
    if legend is None:
        legend=[]
    
    set_figsize(figsize)
    axes = axes if axes else plt.gca()
    # 若X有一个轴，输出True
    def has_one_axis(X):
        return (hasattr(X,"ndim") and X.ndim == 1 or isinstance(X,list)
               and not hasattr(X[0],"__len__"))
    
    if has_one_axis(X):
        X = [X]
    if Y is None:
        X,Y = [[]] * len(X), X
    elif has_one_axis(Y):
        Y = [Y]
    if len(X) != len(Y):
        X = X * len(Y)
    axes.cla()
    for x, y, fmt in zip(X, Y, fmts):
        if len(x):
            axes.plot(x, y, fmt)
        else:
            axes.plot(y, fmt)
    set_axes(axes,xlabel,ylabel,xlim,ylim,xscale,yscale,legend)

# %%
x = np.arange(0,3,0.1)
plot(x,[f(x),2*x-3],'x','f(x)',legend=['f(x)','Tangent line (x=1)'])

# %% [markdown]
# 梯度
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***练习***
# ![image.png](attachment:image.png)

# %%
# QA1
def f2(x):
    return pow(x,3) - 1/x

x = np.arange(0,3,0.1)
plot(x,[f2(x), 4*x-4],'x','f(x)',legend=['f(x)','Tangent line(x=1)'])
# Out:
# C:\Users\37971\AppData\Local\Temp\ipykernel_38708\3966295481.py:3: RuntimeWarning: divide by zero encountered in divide
#   return pow(x,3) - 1/x

# %%
# QA2 [6X1,5*e^x2]
def f3(x):
    return 3 * x[0]**2 + 5 * pow(np.e,x[1])

# %%
def numerical_lim1(f,x,Selected,h):
    if Selected == 0:
        x1 = [x[0]+h,x[1]]
    else:
        x1 = [x[0],x[1]+h]
    return (f(x1)-f(x))/h

# %%
x = [1,1]

h = 0.1
for i in range(5):
    print(f'h={h:.5f}:')
    print(f'numerical_lim(x1):{numerical_lim1(f3,x,0,h):.5f}')
    print(f'numerical_lim(x2):{numerical_lim1(f3,x,1,h):.5f}\n')
    h *= 0.1
# Out:
# h=0.10000:
# numerical_lim(x1):6.30000
# numerical_lim(x2):14.29421
#
# h=0.01000:
# numerical_lim(x1):6.03000
# numerical_lim(x2):13.65959
#
# h=0.00100:
# numerical_lim(x1):6.00300
# numerical_lim(x2):13.59821
#
# h=0.00010:
# numerical_lim(x1):6.00030
# numerical_lim(x2):13.59209
#
# h=0.00001:
# numerical_lim(x1):6.00003
# numerical_lim(x2):13.59148

# %% [markdown]
# QA3:
# ![image.png](attachment:image.png)
# QA4:
# ![image-2.png](attachment:image-2.png)
